# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('~/Downloads/sat_gpa_v1.csv')

# %%
df.head()
# Out:
#    sat_sum  fy_gpa
# 0     1270    3.18
# 1     1220    3.33
# 2     1160    3.25
# 3      950    2.42
# 4     1070    2.63

# %%
df.isna().sum()
# Out:
# sat_sum    0
# fy_gpa     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
single_student = df

# %%
sns.lmplot(data=df, x="sat_sum", y="fy_gpa")
